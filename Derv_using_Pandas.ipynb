# %% [markdown]
# Become an Excel Wizard With Python<br>
# https://www.youtube.com/watch?v=q6Mc_sAPZ2Y
#
# Python 3 Quick Tip: The easy way to deal with file paths on Windows, Mac and Linux<br>
# https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f
#
# Openpyxl: Removing Duplicate cells from a column<br>
# https://stackoverflow.com/questions/42372968/openpyxl-removing-duplicate-cells-from-a-column
#
# How to Perform a SUMIF Function in Pandas?<br>
# https://www.geeksforgeeks.org/how-to-perform-a-sumif-function-in-pandas/
#
# How do I get the row count of a Pandas DataFrame?<br>
# https://stackoverflow.com/questions/15943769/how-do-i-get-the-row-count-of-a-pandas-dataframe
#
# How can I extract the nth row of a pandas data frame as a pandas data frame?<br>
# https://stackoverflow.com/questions/46307490/how-can-i-extract-the-nth-row-of-a-pandas-data-frame-as-a-pandas-data-frame
#
# Pandas loc vs. iloc vs. at vs. iat?<br>
# https://re-thought.com/how-to-change-or-update-a-cell-value-in-python-pandas-dataframe/
#
# Replacing column values in a pandas DataFrame<br>
# https://stackoverflow.com/questions/23307301/replacing-column-values-in-a-pandas-dataframe
#
# Update a dataframe within apply after using groupby<br>
# https://stackoverflow.com/questions/43926479/update-a-dataframe-within-apply-after-using-groupby
#
# Python strftime - date without leading 0?<br>
# Source: https://stackoverflow.com/questions/904928/python-strftime-date-without-leading-0
#
# Formatting dates in Python<br>
# https://www.geeksforgeeks.org/formatting-dates-in-python/
#
# Difference between two dates in Python<br>
# https://stackoverflow.com/questions/8419564/difference-between-two-dates-in-python
#
# How can I subtract a day from a Python date?<br>
# https://www.tutorialspoint.com/How-can-I-subtract-a-day-from-a-Python-date#:~:text=You%20can%20subtract%20a%20day,subtract%20it%20from%20the%20date
#
# Accessing elements of pandas series<br>
# https://www.geeksforgeeks.org/accessing-elements-of-a-pandas-series/
#
# Tutorial: Advanced For Loops in Python (Looping through a series by label):<br>
# https://www.dataquest.io/blog/tutorial-advanced-for-loops-python-pandas/
#
# Python - List Comprehension<br>
# https://www.w3schools.com/python/python_lists_comprehension.asp

# %%
import pandas as pd
import numpy as np
from pathlib import Path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\hilton.netta\py\Derv_using_Pandas.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hilton.netta/py/Derv_using_Pandas.ipynb#ch0000001?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/hilton.netta/py/Derv_using_Pandas.ipynb#ch0000001?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/c%3A/Users/hilton.netta/py/Derv_using_Pandas.ipynb#ch0000001?line=2'>3</a> from pathlib import Path
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# days difference function

def days_between(d1, d2):
    d1 = datetime.strptime(d1, "%Y-%m-%d")
    d2 = datetime.strptime(d2, "%Y-%m-%d")
    return abs((d2 - d1).days)

# %%
import datetime
from datetime import date
from datetime import timedelta

# variables ...
ydy = date.today() - timedelta(days=1)
yday = f'{ydy:%#d}{ydy:%#b}{ydy:%Y}' # current date without leading zeroes, e.g. 3May2021

# ... and paths
pth = Path('//pim-cpt-statpro/SPC_602/Client/Profiles/PIM/Exports')
flnDerv = pth / f'Derivative Exposure {yday}.xlsx'
flnHoldings = pth / f'Portfolio Analytics Report - New {yday}.xlsx'

# %%
wbD = pd.read_excel(open(flnDerv,'rb'), sheet_name = 'Derivative Exposure')
wbH = pd.read_excel(open(flnHoldings,'rb'), sheet_name = 'Portfolio Analytics Report - Ne')
type(wbD), type(wbH)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.frame.DataFrame)

# %%
# list the unique fund codes

fndcodes = wbH.loc[:,'Entity ID'].unique()
print(fndcodes)
# Out:
# ['PLPRNA' 'PLMED' 'ABMMABR' 'ABMMBND' 'ABMMEQU' 'SISLP' 'PSPAM' 'SHNIPF'
#  'ECICBALC' 'ELCIPF' 'ENGENMBF' 'GTCWP2' 'HOLDINC' 'HOLYPF' 'AMMIPF'
#  'GAEMBF' 'GMRETF2' 'GMRETF' 'GRFINV' 'EMHPBQ' 'IJGBAL' 'IJGCOR' 'IJGIPF'
#  'LIBTAA' 'MEDINC' 'MWPFEQU' 'MOMPRET' 'NESEQU' 'NFMWEQU' 'OMFLXI5'
#  'PICPROV' 'PBAL' 'PIMBAL' 'PCAEF' 'PCCEF' 'PCEQTF' 'PCGEF' 'PEQ' 'PABS'
#  'PEAQ' 'PBNDQ' 'PFFIF' 'PGIF' 'PGGF' 'PPOS' 'PPEF' 'PSTIF' 'PSIF' 'PCSHQ'
#  'PORFGPR' 'PPSBAL_C' 'PPSNAM' 'PPWEQU' 'NGKINC' 'POIF_C' 'SAAMCAU'
#  'SAAMMAN' 'SAAMMOD' 'CAPGIP' 'MOMBBF' 'MOMFLX' 'ADRRC' 'ASHFLX' 'ASHGFB'
#  'PPSFLEX' 'STSBND' 'SMMIBF' 'SILEQF' 'SMMAIF' 'SMMBPR' 'SMMEYP' 'SMMRRF'
#  'SWGSWX' 'ASBTOS' 'TOYCEF' 'TSHMPF']

# %%
# find the NAV of each fund; this will be used as a lookup later

nav = wbH.groupby('Entity ID')['Sum of Market Value Income'].sum() # this has type 'pandas.core.series.Series'
nav.head(3)
# Out:
# Entity ID
# ABMMABR    1.651491e+08
# ABMMBND    5.320322e+08
# ABMMEQU    7.016930e+08
# Name: Sum of Market Value Income, dtype: float64

# %%
# get number of rows in nav list
nav.shape[0] # or len(nav)
# Out:
# 76

# %%
fnd = 'ABMMEQU'
print(nav[fnd])
# Out:
# 701692967.0000001

# %%
nav.head(5)
# Out:
# Entity ID
# ABMMABR    1.651491e+08
# ABMMBND    5.320322e+08
# ABMMEQU    7.016930e+08
# ADRRC      6.081068e+07
# AMMIPF     3.089382e+07
# Name: Sum of Market Value Income, dtype: float64

# %%
type(nav)
# Out:
# pandas.core.series.Series

# %%
nav['STSBND']
# Out:
# 118027288.01

# %%
fnd='ABMMBND'
nav[[fnd]][0]
# Out:
# 532032207.36

# %%
for key, value in nav.items() :
    print(value)
# Out:
# 165149100.09
# 532032207.36
# 701692967.0000001
# 60810680.56
# 30893822.37
# 125913746.27
# 253621840.38000003
# 50754593.03000001
# 101601990.14000002
# 536527240.1999998
# 190882594.84
# 0.010000000000218279
# 65709879.24999999
# 105679274.4
# 207494013.51000002
# 131383117.64999999
# 110481958.02000003
# 222677964.01999998
# 665463315.6800002
# 562874434.33
# 35416066.21999999
# 954780358.64
# 1854305728.7900004
# 198111348.79999998
# 117748255.86
# 575291570.6999997
# 4026864794.0899997
# 473144394.06999993
# 672138730.0500001
# 225256675.39
# 1010369996.96
# 103841248.94
# 2625958923.0600004
# 195910583.52999997
# 168401974.04999998
# 1071292859.6899999
# 319200115.41
# 1594002863.1700003
# 965377238.8199998
# 48993399.519999996
# 1254401215.98
# 15390804.729999999
# 222343186.26999998
# 3162108980.049999
# 5251638.9
# 136871809.8
# 50090037.120000005
# 2546268322.76
# 109666956.34000002
# 29914854.2
# 257136143.8
# 613082907.66
# 368371276.5600002
# 220409240.25
# 1364929992.6200004
# 678521259.4100002
# 692871814.8599999
# 140756326.27999997
# 226401847.77000004
# 172458926.28000003
# 499654420.6800001
# 52066397.5
# 74436793.32000001
# 55827724.440000005
# 137305485.83
# 34915352.99999999
# 977822890.2
# 541662106.74
# 345639610.11999995
# 241206657.04000002
# 4963125668.61
# 211094289.87
# 118027288.01
# 296989017.3499999
# 566524918.3299999
# 175926354.57000008

# %%
# can't set element values through a subset
wbH[wbH['Entity ID'] == fnd]['% of Total Market Value'].iat[3] = 19
wbH[wbH['Entity ID'] == fnd]['% of Total Market Value'].iat[3]
# Out:
# 0.0087411

# %%
newTMV = [x+4 for x in wbH['% of Total Market Value']]
newTMV
# Out:
# [4.00160453,
#  4.0146914,
#  4.00058347,
#  4.0,
#  4.00213442,
#  4.00167604,
#  4.00165388,
#  4.00162627,
#  4.00186309,
#  4.00162144,
#  4.00140465,
#  4.00303808,
#  4.00000041,
#  3.99995146,
#  3.99997222,
#  3.99998994,
#  3.99998776,
#  4.00025915,
#  4.01169873,
#  4.00683177,
#  4.00545797,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00294974,
#  4.00216838,
#  4.00152483,
#  4.00044048,
#  4.00107884,
#  4.0034022,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.01262487,
#  4.0072204,
#  4.04948682,
#  4.00518948,
#  4.00630147,
#  4.00369869,
#  4.00797913,
#  4.0060544,
#  4.00594523,
#  4.00684058,
#  4.00602249,
#  4.0,
#  4.01280787,
#  4.00472387,
#  4.00000086,
#  4.00020407,
#  3.99990183,
#  3.99995504,
#  4.00046871,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00136144,
#  4.00131239,
#  4.004518,
#  4.00111009,
#  4.00078287,
#  4.00400841,
#  4.00276744,
#  4.00177982,
#  4.0006204,
#  4.001093,
#  4.01614214,
#  4.01617179,
#  4.00697573,
#  4.00459256,
#  4.00715455,
#  4.01373817,
#  4.00629169,
#  4.00615433,
#  4.0014289,
#  4.00556554,
#  4.01243357,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.01315717,
#  4.0068616,
#  4.00253068,
#  4.00826845,
#  4.00791501,
#  4.00770481,
#  4.00786945,
#  4.00784983,
#  4.02165453,
#  4.01453631,
#  4.00001187,
#  4.00096732,
#  4.00016783,
#  4.00127919,
#  4.00442739,
#  4.03033093,
#  4.02416423,
#  4.07437995,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.02075419,
#  4.02749468,
#  4.03465384,
#  4.00688884,
#  4.01178671,
#  4.01125412,
#  4.00819306,
#  4.00235349,
#  4.00616056,
#  4.01501412,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00247803,
#  4.00404958,
#  4.00355863,
#  4.0087411,
#  4.0351793,
#  5.15881833,
#  4.0,
#  4.00000382,
#  4.00371792,
#  4.00322039,
#  4.05280088,
#  4.01285128,
#  4.04142042,
#  4.08719965,
#  4.00000048,
#  4.20866686,
#  4.01925736,
#  4.00000176,
#  4.00183019,
#  4.00202194,
#  4.0,
#  4.00190905,
#  4.00458823,
#  4.00086112,
#  4.00646621,
#  4.00560072,
#  4.00051011,
#  4.00199321,
#  4.0011537,
#  4.00391177,
#  4.0051014,
#  4.00598225,
#  4.00056587,
#  4.00506719,
#  4.00244318,
#  4.00569657,
#  4.00192632,
#  4.00345399,
#  4.00159065,
#  4.00348207,
#  4.00886663,
#  4.00385884,
#  4.01091919,
#  4.00743839,
#  4.00476164,
#  4.30433976,
#  4.30693849,
#  4.00140898,
#  4.00235296,
#  4.00361411,
#  4.00292906,
#  4.00252301,
#  4.00071221,
#  4.00188537,
#  4.00140173,
#  4.00350648,
#  4.00037178,
#  4.00156416,
#  4.00183324,
#  4.00321828,
#  4.00653634,
#  4.00904252,
#  4.00743298,
#  4.00597327,
#  4.00249579,
#  4.00148803,
#  4.00214492,
#  4.00647193,
#  4.00244924,
#  4.00492415,
#  4.00600954,
#  4.00449864,
#  4.00049243,
#  4.00476452,
#  4.00280744,
#  4.00161279,
#  4.00156759,
#  4.00267524,
#  4.00262191,
#  4.00247618,
#  4.07929422,
#  4.00066258,
#  4.04557576,
#  4.02611433,
#  4.03596108,
#  4.03746008,
#  4.14729946,
#  4.0,
#  3.99965749,
#  3.99543171,
#  4.0,
#  6.1257370600000005,
#  4.00458953,
#  4.00000002,
#  4.00000228,
#  4.00300871,
#  4.10847439,
#  4.02027264,
#  4.01263205,
#  4.07693655,
#  4.00838124,
#  4.00352416,
#  4.00408802,
#  4.00877705,
#  4.00987744,
#  4.00877149,
#  4.00861126,
#  4.0111229,
#  4.00972864,
#  4.01569967,
#  4.01761001,
#  4.00000162,
#  3.99926705,
#  4.00151551,
#  4.07037522,
#  4.0314076,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.01168577,
#  4.01754932,
#  4.00956027,
#  4.00907074,
#  4.00275168,
#  4.0067336,
#  4.0194376,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00232437,
#  4.00459002,
#  4.00290947,
#  4.00441295,
#  4.00103966,
#  4.00069456,
#  4.0006946,
#  4.00697972,
#  4.00463706,
#  4.00060143,
#  4.00328029,
#  4.00515481,
#  4.00859702,
#  4.00924056,
#  4.00169839,
#  4.00291712,
#  4.00464846,
#  4.00115046,
#  4.00117769,
#  4.00097127,
#  4.00690203,
#  4.00234561,
#  4.0048515,
#  4.0017646,
#  4.00897653,
#  4.00162289,
#  4.00113412,
#  4.00321537,
#  4.00288419,
#  4.00465666,
#  4.00118043,
#  4.00174504,
#  4.00567866,
#  4.00276739,
#  4.00233525,
#  4.00162468,
#  4.00347025,
#  4.00023166,
#  4.00344984,
#  4.00282706,
#  4.00056843,
#  4.00395898,
#  4.00643874,
#  4.00296435,
#  4.00086639,
#  4.00459486,
#  4.00505081,
#  4.00459768,
#  4.02686722,
#  4.00183698,
#  4.00047816,
#  4.00385971,
#  4.02442685,
#  4.00032714,
#  4.00362163,
#  4.00444399,
#  4.00162597,
#  4.00688641,
#  4.00000152,
#  4.00400814,
#  4.00000599,
#  4.00156664,
#  4.00000473,
#  4.0,
#  4.0,
#  4.00001133,
#  4.0,
#  4.0,
#  4.00000392,
#  4.0,
#  4.0,
#  4.00172434,
#  4.00231687,
#  4.00468159,
#  4.00699655,
#  4.01367054,
#  4.00229628,
#  4.00462939,
#  4.00059802,
#  4.00424107,
#  4.00114959,
#  4.00447802,
#  4.00206888,
#  4.00656297,
#  4.00138889,
#  4.00296183,
#  4.00641221,
#  4.00424322,
#  4.00397378,
#  4.08536182,
#  4.1032101,
#  4.06232622,
#  4.00000031,
#  4.00185696,
#  3.99969746,
#  4.34535857,
#  4.06531757,
#  4.00080732,
#  4.00196,
#  4.07197892,
#  4.00865373,
#  4.01040813,
#  4.01159068,
#  4.00376696,
#  4.00607911,
#  4.01445386,
#  4.00247494,
#  4.01362723,
#  4.00236685,
#  4.01042256,
#  4.00546835,
#  4.00086445,
#  4.00186935,
#  4.00224295,
#  4.01481347,
#  4.01272016,
#  4.00217101,
#  4.00340313,
#  4.00153419,
#  4.01168882,
#  4.06803716,
#  4.00091312,
#  4.00168316,
#  4.00063288,
#  4.00826798,
#  4.00582828,
#  4.00079048,
#  4.00054565,
#  4.00118915,
#  4.00430781,
#  4.00361951,
#  4.00250503,
#  4.00134095,
#  4.00968038,
#  4.00327063,
#  4.00224561,
#  4.00158756,
#  4.00449534,
#  4.0100829,
#  4.01482262,
#  4.00078422,
#  4.00622903,
#  4.00101935,
#  4.02638757,
#  4.00093668,
#  4.00335505,
#  4.00080825,
#  4.00200583,
#  4.00511324,
#  4.0000605,
#  4.00063008,
#  4.00061101,
#  4.00121651,
#  4.00781016,
#  4.00311076,
#  4.00047526,
#  4.00056744,
#  4.00470147,
#  4.00103347,
#  4.00178986,
#  4.00250542,
#  4.00270476,
#  4.00312283,
#  4.00132581,
#  4.00940948,
#  4.00083011,
#  4.00046777,
#  4.01804792,
#  4.00187744,
#  4.00078224,
#  4.00570383,
#  4.00209488,
#  4.00191844,
#  4.00151138,
#  4.0015698,
#  4.00010651,
#  4.00089998,
#  4.00056922,
#  4.00599126,
#  4.00051993,
#  4.00071787,
#  4.00060568,
#  4.00574223,
#  4.02454426,
#  4.01254474,
#  4.02297895,
#  4.00085323,
#  4.00656509,
#  4.0,
#  4.00057448,
#  4.0,
#  4.00901006,
#  4.00853863,
#  4.05257144,
#  4.0070207,
#  4.00000601,
#  4.00097901,
#  3.99994948,
#  4.00062672,
#  4.27402659,
#  4.0,
#  4.0,
#  4.00076669,
#  4.00209339,
#  4.00212231,
#  4.00039312,
#  4.00158422,
#  4.00271214,
#  4.00030194,
#  4.0012092,
#  4.00195667,
#  4.0013596,
#  4.00004749,
#  4.00036181,
#  4.00201392,
#  4.00107211,
#  4.00187816,
#  4.00088838,
#  4.00070155,
#  4.00147629,
#  4.00035366,
#  4.00324253,
#  4.00178837,
#  4.00274046,
#  4.00178981,
#  4.0010636,
#  4.00133854,
#  4.00421151,
#  4.00148118,
#  4.00050335,
#  4.00042093,
#  4.00072081,
#  4.00086226,
#  4.00093449,
#  4.0015536,
#  4.00053563,
#  4.00066067,
#  4.00098703,
#  4.00249078,
#  4.00325282,
#  4.00229999,
#  4.00349745,
#  4.0013612,
#  4.00099709,
#  4.00006347,
#  4.00186231,
#  4.0004708,
#  4.00215675,
#  4.00206828,
#  4.00154186,
#  4.00203015,
#  4.00111152,
#  4.00027283,
#  4.0005966,
#  4.00099707,
#  4.00115809,
#  4.00442024,
#  4.00021926,
#  4.00471073,
#  4.00092773,
#  4.0003566,
#  4.0,
#  3.99991025,
#  3.99896004,
#  4.0,
#  3.99992417,
#  3.99911408,
#  4.0,
#  4.0,
#  4.00752637,
#  4.00529496,
#  4.02732085,
#  4.00312287,
#  4.00378088,
#  4.00194668,
#  4.00398957,
#  4.0036031,
#  4.00354581,
#  4.00408767,
#  4.0036032,
#  4.00702727,
#  4.00310068,
#  4.00000058,
#  4.00036179,
#  3.9999558,
#  4.00000137,
#  4.00030878,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00081163,
#  4.00078386,
#  4.00269944,
#  4.0006644,
#  4.00046865,
#  4.00239359,
#  4.00165358,
#  4.00106305,
#  4.00037174,
#  4.00065278,
#  4.00922408,
#  4.01155128,
#  4.00232524,
#  4.00229628,
#  4.00434043,
#  4.00915878,
#  4.00377093,
#  4.00388798,
#  4.00330054,
#  4.00097413,
#  4.00217945,
#  4.00750012,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.02684659,
#  4.04486402,
#  4.00000269,
#  3.9989713,
#  3.99980668,
#  4.00410147,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.09517534,
#  4.00342585,
#  4.08532277,
#  4.02291223,
#  4.04851537,
#  4.02750755,
#  4.04306777,
#  4.11000445,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.01861258,
#  4.00451405,
#  4.04681638,
#  4.00937238,
#  4.00929408,
#  4.02178732,
#  4.00911064,
#  4.00141323,
#  4.03253921,
#  4.04744418,
#  4.01248126,
#  4.02070609,
#  4.00468794,
#  4.00950551,
#  4.00277459,
#  4.01070868,
#  4.00578132,
#  4.0091937,
#  4.01399475,
#  4.00932405,
#  4.01309114,
#  4.00931332,
#  4.01543994,
#  4.00115956,
#  4.00077192,
#  4.01033557,
#  4.01411803,
#  4.0016216,
#  4.0156393,
#  4.0026169,
#  4.00170839,
#  4.00232881,
#  4.02851443,
#  4.01710204,
#  4.00368214,
#  4.02848816,
#  4.02850563,
#  4.17315233,
#  4.00757756,
#  4.02276009,
#  4.00113361,
#  4.00161172,
#  4.09026924,
#  4.00094952,
#  4.01840887,
#  4.19262958,
#  4.07109214,
#  4.0000035,
#  4.0050443,
#  4.0003633,
#  4.09230948,
#  4.01308827,
#  4.0026713,
#  4.00830597,
#  4.0000163,
#  4.0,
#  4.0,
#  4.0000135,
#  4.0,
#  4.0,
#  3.97565799,
#  4.02574552,
#  4.01027755,
#  4.01685703,
#  4.01992505,
#  4.00580043,
#  4.00184162,
#  4.00184162,
#  4.05303848,
#  4.01386153,
#  4.0058011,
#  4.00462567,
#  4.00896515,
#  4.01408271,
#  4.01134257,
#  4.00368361,
#  4.0027661,
#  4.01905484,
#  4.00462974,
#  4.03931841,
#  4.01635023,
#  4.01811516,
#  4.01677269,
#  4.03942459,
#  4.00439913,
#  4.08719993,
#  4.00855877,
#  4.01616716,
#  4.06677823,
#  4.03299399,
#  4.0139982,
#  4.00327034,
#  4.06972689,
#  4.00420491,
#  4.00308319,
#  4.00232423,
#  4.00179493,
#  4.02095909,
#  4.01610473,
#  4.00421915,
#  4.0083463,
#  4.00177075,
#  4.01474637,
#  4.00462506,
#  4.0091937,
#  4.00458844,
#  4.01364496,
#  4.02095496,
#  4.00483938,
#  4.01368285,
#  4.00689038,
#  4.01646949,
#  4.00138994,
#  4.01379938,
#  4.00155863,
#  4.0009745,
#  4.01107267,
#  4.01490441,
#  4.00798095,
#  4.00389874,
#  4.01015459,
#  4.02188684,
#  4.15650208,
#  4.00757756,
#  4.01488197,
#  4.00138147,
#  4.09681302,
#  4.00087372,
#  4.00109544,
#  4.0275314,
#  4.02294345,
#  4.00000294,
#  4.00350981,
#  4.00216733,
#  4.00002005,
#  4.0,
#  4.0,
#  4.00003535,
#  4.0,
#  4.0,
#  4.00001661,
#  4.0,
#  4.0,
#  3.98299468,
#  4.01798581,
#  4.01160186,
#  4.01027754,
#  4.02540101,
#  4.0139012,
#  4.00368324,
#  4.00368324,
#  4.02767225,
#  4.02304985,
#  4.02738978,
#  4.02784527,
#  4.01599541,
#  4.02983557,
#  4.02539505,
#  4.01018516,
#  4.00529519,
#  4.00391864,
#  4.0391786,
#  4.00925947,
#  4.00224338,
#  4.07401113,
#  4.001166,
#  4.01838229,
#  4.00762128,
#  4.00295826,
#  4.01043239,
#  4.00458953,
#  4.0068843,
#  4.00000373,
#  4.00450315,
#  4.00003767,
#  4.01541632,
#  4.01228497,
#  4.00465315,
#  4.04587841,
#  4.00489097,
#  4.00606809,
#  4.00428269,
#  4.00927574,
#  4.00578859,
#  4.00570529,
#  4.00661813,
#  4.00581659,
#  4.01400876,
#  4.00452376,
#  4.00000072,
#  4.00013895,
#  3.99988158,
#  4.00044933,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00131302,
#  4.0012679,
#  4.00436682,
#  4.00107444,
#  4.00075871,
#  4.00387802,
#  4.0026872,
#  4.00172008,
#  4.00060233,
#  4.00105656,
#  4.01383612,
#  4.02310256,
#  4.00232524,
#  4.00459256,
#  4.00698761,
#  4.01144847,
#  4.00606495,
#  4.00602434,
#  4.00143195,
#  4.00542459,
#  4.01205707,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0039317,
#  4.00529496,
#  4.05007963,
#  4.00513453,
#  4.00253068,
#  4.00526623,
#  4.00603373,
#  4.00608393,
#  4.00591857,
#  4.00589514,
#  4.00591954,
#  4.00632017,
#  4.01214315,
#  4.00000134,
#  3.99982169,
#  4.00006713,
#  3.99985212,
#  4.00105603,
#  4.03702107,
#  4.02407575,
#  4.01926656,
#  4.05630355,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00171293,
#  4.00881654,
#  4.00841907,
#  4.00612898,
#  4.00176059,
#  4.00460868,
#  4.01175236,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00740085,
#  4.00946674,
#  4.0799006,
#  4.00861201,
#  4.00350402,
#  4.0077996,
#  4.01027969,
#  4.0097461,
#  4.00946439,
#  4.00967692,
#  4.00967716,
#  4.01000974,
#  4.01883743,
#  4.00004056,
#  4.00000221,
#  3.99936188,
#  4.0,
#  3.99976632,
#  4.00166185,
#  4.05075956,
#  4.03805396,
#  4.0304405,
#  4.09266957,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.01480386,
#  4.0141356,
#  4.01029073,
#  4.0029561,
#  4.00773788,
#  4.01865664,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.0,
#  4.00463179,
#  4.00465501,
#  4.00463704,
#  4.00462842,
#  4.00460894,
#  4.00233377,
#  4.00584324,
#  4.00471259,
#  4.00397458,
#  4.00460273,
#  4.00440648,
#  4.00148108,
#  4.00818344,
#  4.00185063,
#  4.00183597,
#  4.00181992,
#  4.0025272,
#  4.00276625,
#  4.00463951,
#  4.00393588,
#  4.00207097,
#  4.00136669,
#  4.00079925,
#  4.00256289,
#  4.00343566,
#  4.00108348,
#  4.00548858,
#  4.00120313,
#  4.01193965,
#  4.00137835,
#  4.00067552,
#  4.00219587,
#  4.00209938,
#  4.00229529,
#  4.00229529,
#  4.00000201,
#  4.00139856,
#  4.00122506,
#  4.04992702,
#  4.01605472,
#  4.00174656,
#  3.99054398,
#  4.01000124,
#  4.00514238,
#  4.00579788,
#  4.0046438,
#  4.00231187,
#  4.00689124,
#  4.00465821,
#  4.00160971,
#  4.0039264,
#  4.00532585,
#  4.00391519,
#  4.00230587,
#  ...]

# %%
for value in wbH['% of Total Market Value']:
    wbH.iat[value,13]=i
    
wbH['% of Total Market Value']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-1969ef13baa3> in <module>
#       1 for value in wbH['% of Total Market Value']:
# ----> 2     wbH.iat[value,13]=i
#       3
#       4 wbH['% of Total Market Value']
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#    2112         if not isinstance(key, tuple):
#    2113             key = _tuplify(self.ndim, key)
# -> 2114         key = list(self._convert_key(key, is_setter=True))
#    2115         if len(key) != self.ndim:
#    2116             raise ValueError("Not enough indexers for scalar access (setting)!")
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _convert_key(self, key, is_setter)
#    2178         for a, i in zip(self.obj.axes, key):
#    2179             if not is_integer(i):
# -> 2180                 raise ValueError("iAt based indexing can only have integer indexers")
#    2181         return key
#    2182
#
# ValueError: iAt based indexing can only have integer indexers

# %%
for i in wbH['% of Total Market Value'].iterrows():
# Out:
#   File "<ipython-input-109-432352a80ad6>", line 1
#     for i in wbH['% of Total Market Value'].iterrows():
#                                                        ^
# SyntaxError: unexpected EOF while parsing

# %%
wbH['% of Total Market Value'][2]
# Out:
# 14876.00058347

# %%
for i in wbH['% of Total Market Value']:
    wbH['% of Total Market Value'][i] = 4
    
wbH['% of Total Market Value']
# Out:
# <ipython-input-79-742cf1a2a58a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wbH['% of Total Market Value'][i] = 4
# 0       14876.001605
# 1       14876.014691
# 2       14876.000583
# 3       14876.000973
# 4       14876.002134
#             ...
# 3714    14876.000000
# 3715    14875.999936
# 3716    14875.999252
# 3717    14876.000000
# 3718    14876.000000
# Name: % of Total Market Value, Length: 3719, dtype: float64

# %%
wbH['% of Total Market Value'] = wbH['% of Total Market Value'].map({'% of Total Market Value': '1'})

# %%
wbH['% of Total Market Value']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 3719    NaN
# 3720    NaN
# 3721    NaN
# 3722    NaN
# 3723    NaN
# Name: % of Total Market Value, Length: 3724, dtype: object
